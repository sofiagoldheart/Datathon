# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiagoldheart/Datathon/blob/main/Violencia%20de%20agresores%20hacia%20la%20mujer%20a%20lo%20largo%20de%20su%20vida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# Librerias utilizadas para la representación y análisis de datos
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Violencia de agresores hacia la mujer a lo largo de su vida

# %%
# Load the dataset
datathonset = pd.read_csv('/content/drive/MyDrive/datathon/Copia de Violencia_cualquier_agresor_largo_de_su_vida.csv', encoding='ISO-8859-1')
# Visualize the dataset
datathonset
# Out:
#                 Entidad federativa   2006  2011  2016
# 0                          Nacional  52.0  41.4  52.7
# 1                    Aguascalientes  54.1  41.4  59.1
# 2                   Baja California  45.5  43.8  51.1
# 3               Baja California Sur  44.2  34.0  40.3
# 4                          Campeche  42.9  36.8  41.2
# 5              Coahuila de Zaragoza  45.0  34.1  50.8
# 6                            Colima  55.0  41.6  47.6
# 7                           Chiapas  31.3  25.5  39.0
# 8                         Chihuahua  50.1  42.6  51.9
# 9                  Ciudad de México  67.2  56.9  70.8
# 10                          Durango  51.4  35.3  51.4
# 11                       Guanajuato  46.5  39.4  52.4
# 12                         Guerrero  43.3  32.9  41.8
# 13                          Hidalgo  40.3  32.8  49.3
# 14                          Jalisco  60.3  41.9  61.3
# 15                           México  65.4  52.5  63.0
# ...
