# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiagoldheart/Datathon/blob/main/Mujeres%20que%20han%20pedido%20ayuda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# Librerias utilizadas para la representación y análisis de datos
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Mujeres que han pedido ayuda

# %%
# Load the dataset
datathonset = pd.read_csv('/content/drive/MyDrive/datathon/Copia de Violencia_ayuda.csv', encoding='ISO-8859-1')
# Visualize the dataset
datathonset.ñ
# Out:
#                  Entidad federativa   2006   2011   2016
# 0                          Nacional  22.42  22.23  11.58
# 1                    Aguascalientes  21.79  22.43  10.88
# 2                   Baja California  24.48  27.07  15.47
# 3               Baja California Sur  27.14  19.50  12.46
# 4                          Campeche  24.00  24.97  15.22
# 5              Coahuila de Zaragoza  24.02  22.01  11.46
# 6                            Colima  28.31  24.92  11.38
# 7                           Chiapas  19.39  21.88  12.83
# 8                         Chihuahua  21.66  24.84  10.52
# 9                  Ciudad de México  22.76  23.87  14.38
# 10                          Durango  17.47  17.59   7.79
# 11                       Guanajuato  22.94  20.63  11.17
# 12                         Guerrero  16.66  15.04  12.28
# 13                          Hidalgo  28.09  23.51  12.61
# 14                          Jalisco  18.48  19.53  10.15
# ...
