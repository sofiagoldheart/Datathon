# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiagoldheart/Datathon/blob/main/Violencia%20f%C3%ADsica%20o%20sexual%20ultimos%2012%20meses.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# Librerias utilizadas para la representación y análisis de datos
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Violencia física o sexual ultimos 12 meses

# %%
# Load the dataset
datathonset = pd.read_csv('/content/drive/MyDrive/datathon/Copia de Violencia_física_o_sexual_ultimos_12_meses.csv', encoding='ISO-8859-1')
# Visualize the dataset
datathonset
# Out:
#                  Entidad Federativa  2006  2011  2016
# 0                          Nacional  13.3   7.8   9.1
# 1                    Aguascalientes  13.7   7.8   9.5
# 2                   Baja California  10.8   5.4   5.3
# 3               Baja California Sur  10.5   5.7   6.1
# 4                          Campeche  11.0   7.6   7.2
# 5              Coahuila de Zaragoza  11.3   6.8   7.7
# 6                            Colima  15.4   8.5   9.4
# 7                           Chiapas   9.6   5.8   6.7
# 8                         Chihuahua  12.2   8.6   7.8
# 9                  Ciudad de México  14.3   7.0  10.8
# 10                          Durango  15.1   8.7   9.0
# 11                       Guanajuato  11.8   8.7   8.5
# 12                         Guerrero  15.2   9.0   9.3
# 13                          Hidalgo  12.6   8.4  11.0
# 14                          Jalisco  13.9   7.6  10.9
# 15                           México  16.6   9.2  11.8
# ...
