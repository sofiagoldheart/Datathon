# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiagoldheart/Datathon/blob/main/Mujeres%20Diputadas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Librerias utilizadas para la representación y análisis de datos
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # MUJERES DIPUTADAS
#
# [Referencia](https://datos.gob.mx/busca/dataset/estadisticas-de-mujeres-de-inmujeres-creado-el-2015-10-22-03-01/resource/2d92aea2-c85f-4a99-8bf9-62236d2fd208)

# %%
# Load the dataset
datathonset = pd.read_csv('/content/drive/MyDrive/DatasetsDatathon/Mujeres_Diputadas.csv', encoding='ISO-8859-1')
# Visualize the dataset
datathonset
# Out:
#      Entidad   Año  Diputadas  Diputados  Total  %_diputadas  %_diputados
# 0   Nacional  2003        115        385    500         23.0         77.0
# 1   Nacional  2004        113        387    500         22.6         77.4
# 2   Nacional  2005        118        382    500         23.6         76.4
# 3   Nacional  2006        114        386    500         22.8         77.2
# 4   Nacional  2007        116        384    500         23.2         76.8
# 5   Nacional  2008        125        375    500         25.0         75.0
# 6   Nacional  2009        140        359    500         28.0         71.8
# 7   Nacional  2010        135        365    500         27.0         73.0
# 8   Nacional  2011        139        361    500         27.8         72.2
# 9   Nacional  2012        184        316    500         36.8         63.2
# 10  Nacional  2013        184        316    500         36.8         63.2
# 11  Nacional  2014        211        289    500         42.2         57.8
# ...

# %%
datathonset
# Out:
#                   Entidad federativa   Año    Total  Mujeres  Hombres  \
# 0                              Total  2005  1900256   645683  1254573
# 1                     Aguascalientes  2005    27087    11162    15925
# 2                    Baja California  2005    45528    15743    29785
# 3                Baja California Sur  2005    19533     6927    12606
# 4                           Campeche  2005    22367     7020    15347
# ..                               ...   ...      ...      ...      ...
# 523                       Tamaulipas  2020    74450    32438    42012
# 524                         Tlaxcala  2020    22733    11314    11419
# 525  Veracruz de Ignacio de la Llave  2020   139400    56335    83065
# 526                          Yucatán  2020    45142    15548    29594
# 527                        Zacatecas  2020    46750    20381    26369
#
#      %_mujeres  %_hombres
# 0        33.98      66.02
# 1        41.21      58.79
# 2        34.58      65.42
# ...
