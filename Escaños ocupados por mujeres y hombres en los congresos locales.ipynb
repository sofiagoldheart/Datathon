# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiagoldheart/Datathon/blob/main/EscaniosNacionalYEstatal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Librerias utilizadas para la representación y análisis de datos
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the dataset
datathonset = pd.read_csv("/content/drive/MyDrive/Datasets/EscaniosNacionalYEstatal.csv", encoding = "latin-1")
# Visualize the dataset
datathonset
# Out:
#                  Entidad   Año  Total  Diputadas_locales  Diputados_locales  \
# 0        Aguascalientes   2019     27                 14                 13
# 1       Baja California   2019     25                  9                 16
# 2   Baja California Sur   2019     21                 12                  9
# 3              Campeche   2019     35                 18                 17
# 4               Chiapas   2019     41                 27                 14
# ..                   ...   ...    ...                ...                ...
# 59            Tamaulipas  2020     38                 16                 22
# 60              Tlaxcala  2020     25                 15                 10
# 61              Veracruz  2020     43                 21                 22
# 62               Yucatán  2020     25                 13                 12
# 63             Zacatecas  2020     29                 16                 13
#
#     %_diputadas  %_diputados
# ...
