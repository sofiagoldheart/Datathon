# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiagoldheart/Datathon/blob/main/Horas%20semanales%20de%20trabajo%20no%20remunerado%20en%20cuidados%20domiciliarios%20mujeres.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Librerias utilizadas para la representación y análisis de datos
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # HORAS PROMEDIO SEMANALES DEDICADAS A REALIZAR TRABAJO DE CUIDADO NO REMUNERADO PARA EL HOGAR Y PARA OTROS HOGARES

# %%
# Load the dataset
datathonset = pd.read_csv('/content/drive/MyDrive/DatasetsDatathon/Horas_cuidado.csv', encoding='ISO-8859-1')
# Visualize the dataset
datathonset
# Out:
#                             Entidad   Año Población_total Población_hombres  \
# 0                          Nacional  2019      57,190,226        25,268,216
# 1                    Aguascalientes  2019         600,401           257,968
# 2                   Baja California  2019       1,519,841           646,419
# 3               Baja California Sur  2019         335,274           142,190
# 4                          Campeche  2019         485,479           221,759
# 5              Coahuila de Zaragoza  2019       1,544,311           727,758
# 6                            Colima  2019         350,494           162,608
# 7                           Chiapas  2019       2,372,628           983,099
# 8                         Chihuahua  2019       1,809,574           829,108
# 9                  Ciudad de México  2019       3,613,768         1,655,600
# 10                          Durango  2019         872,875           376,550
# ...

# %%
print(datathonset.columns)
# Out:
# Index(['Entidad', 'Año', 'Población_total', 'Población_hombres',
#        'Población_mujeres', 'Horas_totales', 'Horas_hombres', 'Horas_mujeres',
#        'hrs_promedio_total', 'hrs_promedio_hombres', 'hrs_promedio_mujeres',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18'],
#       dtype='object')

# %%
columns_to_visualize = ['hrs_promedio_total', 'hrs_promedio_hombres', 'hrs_promedio_mujeres']

# Create a bar chart for each column
for column in columns_to_visualize:
    plt.figure(figsize=(10, 6))  # Set the size of the figure
    plt.bar(datathonset['Entidad'], datathonset[column])  # Create the bar chart
    plt.xlabel('Entidad')  # X-axis label
    plt.ylabel('Hours')  # Y-axis label
    plt.title(f'Average Hours Worked - {column}')  # Chart title
    plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
    plt.show()  # Display the chart
