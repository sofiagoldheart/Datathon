# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiagoldheart/Datathon/blob/main/Mujeres%20propietarias%20de%20vivienda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# Librerias utilizadas para la representación y análisis de datos
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Mujeres propietarias de vivienda

# %%
# Load the dataset
datathonset = pd.read_csv('/content/drive/MyDrive/datathon/Copia de MujeresPropietariasVivienda.csv', encoding='ISO-8859-1')
# Visualize the dataset
datathonset
# Out:
#       Entidad     Año Propietarias     Mujeres  %_propietarias
# 0    Nacional  2006.0    7,499,632  56,327,411            13.3
# 1    Nacional  2008.0    7,207,204  57,701,039            12.5
# 2    Nacional  2010.0    7,945,439  58,861,256            13.5
# 3    Nacional  2012.0    8,647,264  60,253,424            14.4
# 4    Nacional  2014.0    9,159,645  61,672,648            14.9
# ..        ...     ...          ...         ...             ...
# 193       NaN     NaN          NaN         NaN             NaN
# 194       NaN     NaN          NaN         NaN             NaN
# 195       NaN     NaN          NaN         NaN             NaN
# 196       NaN     NaN          NaN         NaN             NaN
# 197       NaN     NaN          NaN         NaN             NaN
#
# [198 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# ...
