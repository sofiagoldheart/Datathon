# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiagoldheart/Datathon/blob/main/Feminicidio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# Librerias utilizadas para la representación y análisis de datos
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Porcentaje de Feminicidio
#
# [Referencia](https://datos.gob.mx/busca/dataset/estadisticas-de-mujeres-indicadores-de-inclusion-social-igualdad-y-empoderamiento/resource/936be0cb-e8f1-4825-90b0-30be0312edfb)

# %%
# Load the dataset
datathonset = pd.read_csv('/content/drive/MyDrive/datathon/Copia de Tasa_bruta_homicidio.csv', encoding='ISO-8859-1')
# Visualize the dataset
datathonset
# Out:
#                             Entidad    Año  Tasa
# 0                     Aguascalientes  1990  0.79
# 1                    Baja California  1990  3.38
# 2                Baja California Sur  1990  0.00
# 3                           Campeche  1990  2.54
# 4               Coahuila de Zaragoza  1990  0.49
# ..                               ...   ...   ...
# 985                         Tlaxcala  2019  3.58
# 986  Veracruz de Ignacio de la Llave  2019  3.64
# 987                          Yucatán  2019  0.35
# 988                        Zacatecas  2019  8.80
# 989                         Nacional  2019  5.65
#
# [990 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
# ...
