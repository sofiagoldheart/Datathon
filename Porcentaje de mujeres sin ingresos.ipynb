# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiagoldheart/Datathon/blob/main/Porcentaje%20de%20mujeres%20sin%20ingresos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# Librerias utilizadas para la representación y análisis de datos
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Porcentaje de mujeres sin ingresos

# %%
# Load the dataset
datathonset = pd.read_csv('/content/drive/MyDrive/datathon/Copia de MujeresSinIngresos.csv', encoding='ISO-8859-1')
# Visualize the dataset
datathonset
# Out:
#            Entidad   Año Mujeres Sin ingresos propios  \
# 0         Nacional  2008                   13,207,951
# 1         Nacional  2010                   13,121,529
# 2         Nacional  2012                   12,881,418
# 3         Nacional  2014                   12,701,430
# 4         Nacional  2016                   10,844,012
# ..             ...   ...                          ...
# 65      Tamaulipas  2018                      342,624
# 66        Tlaxcala  2018                      126,796
# 67  Veracruz-Llave  2018                      682,228
# 68         Yucatán  2018                      157,340
# 69       Zacatecas  2018                      149,377
#
#    Mujeres que no asisten a la escuela  %_mujeres_sin_ingresos_propios
# 0                           36,291,062                           36.39
# 1                           37,488,256                           35.00
# 2                           38,895,488                           33.12
# ...
