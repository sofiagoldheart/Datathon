# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiagoldheart/Datathon/blob/main/Trabajo%20no%20renumerado%20respecto%20al%20PIB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# Librerias utilizadas para la representación y análisis de datos
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Trabajo no renumerado respecto al PIB
#
# [REFERENCIA](https://datos.gob.mx/busca/dataset/estadisticas-de-mujeres-indicadores-de-inclusion-social-igualdad-y-empoderamiento/resource/6d53f986-3aba-466d-bcf3-788bcf0a9c4b)

# %%
# Load the dataset
datathonset = pd.read_csv('/content/drive/MyDrive/datathon/Copia de Valor_TNRH_PIB.csv', encoding='ISO-8859-1')
# Visualize the dataset
datathonset
# Out:
#     Fecha  %_Total  %_Hombres  %_Mujeres
# 0    2003    20.18       4.11      16.07
# 1    2004    19.41       4.04      15.37
# 2    2005    19.44       4.10      15.34
# 3    2006    18.97       4.12      14.85
# 4    2007    19.67       4.31      15.36
# 5    2008    19.35       4.31      15.04
# 6    2009    20.18       4.61      15.57
# 7    2010    20.43       4.77      15.66
# 8    2011    20.84       4.90      15.95
# 9    2012    21.01       4.98      16.02
# 10   2013    22.08       5.27      16.82
# 11   2014    22.57       5.50      17.07
# 12   2015    22.64       5.63      17.01
# 13   2016    22.37       5.67      16.70
# 14   2017    22.10       5.67      16.44
# 15   2018    22.12       5.75      16.37
# 16   2019    22.82       6.02      16.80
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# ...
