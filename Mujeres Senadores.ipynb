# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiagoldheart/Datathon/blob/main/Mujeres%20Senadores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# Librerias utilizadas para la representación y análisis de datos
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Mujeres Senadores

# %%
# Load the dataset
datathonset = pd.read_csv('/content/drive/MyDrive/datathon/Copia de MujeresSenadoras.csv', encoding='ISO-8859-1')
# Visualize the dataset
datathonset
# Out:
#      Año  Senadores  Senadoras  Total  %_Senadores  %_Senadoras
# 0   2003        101         27    128         78.9         21.1
# 1   2004        104         24    128         81.3         18.8
# 2   2005        101         27    128         78.9         21.1
# 3   2006        106         22    128         82.8         17.2
# 4   2007        104         24    128         81.3         18.8
# 5   2008        103         25    128         80.5         19.5
# 6   2009        102         26    128         79.7         20.3
# 7   2010        100         28    128         78.1         21.9
# 8   2011         98         30    128         76.6         23.4
# 9   2012         85         43    128         66.4         33.6
# 10  2013         85         43    128         66.4         33.6
# 11  2014         85         43    128         66.4         33.6
# 12  2015         84         44    128         65.6         34.4
# 13  2016         81         47    128         63.3         36.7
# ...
