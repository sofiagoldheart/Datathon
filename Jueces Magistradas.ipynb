# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiagoldheart/Datathon/blob/main/Jueces%20Magistradas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Librerias utilizadas para la representación y análisis de datos
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # JUECES MAGISTRADAS
#
# [Referencia](https://datos.gob.mx/busca/dataset/estadisticas-de-mujeres-indicadores-de-inclusion-social-igualdad-y-empoderamiento/resource/7baf54d6-065f-4fa3-b8c4-903bb95f438b)

# %%
# Load the dataset
datathonset = pd.read_csv('/content/drive/MyDrive/DatasetsDatathon/Jueces_magistradas.csv', encoding='ISO-8859-1')
# Visualize the dataset
datathonset
# Out:
#                              Entidad   Año  Total  Hombres  Mujeres  \
# 0                           Nacional  2011   3884     2396     1488
# 1                     Aguascalientes  2011     34       19       15
# 2                    Baja California  2011     91       48       43
# 3                Baja California Sur  2011     32       22       10
# 4                           Campeche  2011     77       50       27
# ..                               ...   ...    ...      ...      ...
# 292                       Tamaulipas  2019    118       77       41
# 293                         Tlaxcala  2019     35       17       18
# 294  Veracruz de Ignacio de la Llave  2019    341      186      155
# 295                          Yucatán  2019     66       25       41
# 296                        Zacatecas  2019    113       55       58
#
#      %_hombres  %_mujeres
# 0        61.69      38.31
# 1        55.88      44.12
# 2        52.75      47.25
# 3        68.75      31.25
# ...

# %%
datathonset
# Out:
#                   Entidad federativa   Año    Total  Mujeres  Hombres  \
# 0                              Total  2005  1900256   645683  1254573
# 1                     Aguascalientes  2005    27087    11162    15925
# 2                    Baja California  2005    45528    15743    29785
# 3                Baja California Sur  2005    19533     6927    12606
# 4                           Campeche  2005    22367     7020    15347
# ..                               ...   ...      ...      ...      ...
# 523                       Tamaulipas  2020    74450    32438    42012
# 524                         Tlaxcala  2020    22733    11314    11419
# 525  Veracruz de Ignacio de la Llave  2020   139400    56335    83065
# 526                          Yucatán  2020    45142    15548    29594
# 527                        Zacatecas  2020    46750    20381    26369
#
#      %_mujeres  %_hombres
# 0        33.98      66.02
# 1        41.21      58.79
# 2        34.58      65.42
# ...
